# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Ali\Programming\MLFall25\Lab01\cancer.csv')
for co in df.columns:
    if(len(df[co]) == df[co].nunique()):
        print(f"{co} is an key")
        break
# Out:
# index is an key

# %%
print(f"Total number of columns is {len(df.columns)}")
print(f"{df.head(50)}\n{df.tail(30)}")
print(f"dimensions: {df.shape}")
print(f"Memory usage:\n{df.memory_usage(deep=True)}")
# Out:
# Total number of columns is 26
#     index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0       0         P1   33       1              2            4             5
# 1       1        P10   17       1              3            1             5
# 2       2       P100   35       1              4            5             6
# 3       3      P1000   37       1              7            7             7
# 4       4       P101   46       1              6            8             7
# 5       5       P102   35       1              4            5             6
# 6       6       P103   52       2              2            4             5
# 7       7       P104   28       2              3            1             4
# 8       8       P105   35       2              4            5             6
# 9       9       P106   46       1              2            3             4
# 10     10       P107   44       1              6            7             7
# ...

# %%
print(f"Number of columns: {len(df.columns)}")
print(f"Number of records: {len(df)}")
# Out:
# Number of columns: 26
# Number of records: 1000

# %%
level_counts = df['Level'].value_counts()
print(level_counts)
plt.pie(level_counts, labels=level_counts.index)
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64
# ([<matplotlib.patches.Wedge at 0x21cb4169650>,
# ...
#  [Text(0.4526656847920056, 1.0025436538185182, 'High'),
#   Text(-1.079199513381086, -0.21290469773592813, 'Medium'),
#   Text(0.6381482218050012, -0.8959725704546515, 'Low')])
