# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Ali\Programming\MLFall25\Lab01\cancer.csv')
plt.figure(figsize=(24, 20))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.histplot(df['Age'], bins=30, kde=True)
plt.show()

sns.histplot(df['Frequent Cold'], bins=30, kde=True)
plt.show()

plt.boxplot(x='Obesity', data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22f98e59f10>,
#   <matplotlib.lines.Line2D at 0x22f98e59bd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x22f98e5ab50>,
#   <matplotlib.lines.Line2D at 0x22f96c4be10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22f98e5b690>],
#  'medians': [<matplotlib.lines.Line2D at 0x22f96c48750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22f96c49650>],
#  'means': []}
