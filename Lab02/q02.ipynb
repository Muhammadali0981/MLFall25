# %%
import pandas as pd
import numpy as np

# %%
counties = [
    "Los Angeles County", "Cook County", "Harris County", "Maricopa County", "San Diego County",
    "Orange County", "Miami-Dade County", "Dallas County", "Kings County", "Riverside County",
    "Queens County", "Clark County", "Tarrant County", "Santa Clara County", "Broward County",
    "Bexar County", "Wayne County", "Alameda County", "Middlesex County", "Sacramento County",
    "Philadelphia County", "Allegheny County", "Fresno County", "Hillsborough County", "New York County",
    "Palm Beach County", "Cuyahoga County", "Honolulu County", "Travis County", "Fairfax County",
    "Hennepin County", "Salt Lake County", "Nassau County", "DuPage County", "Oakland County",
    "Orange County (FL)", "Montgomery County (MD)", "El Paso County", "Baltimore County", "Miami County (OH)",
    "King County (WA)", "Milwaukee County", "Wake County", "Tulsa County", "Pima County",
    "Bergen County", "Fulton County", "Gloucester County", "San Bernardino County", "Hudson County"
]

sizes = ["small", "medium", "high"]
cardinal_directions = ["North", "South", "East", "West"]
Timings = ["full time", "part time"]
conditions = ["excellent", "fine", "abysmal"]
designations = ["janitor", "manager", "team lead"]

size_data = [sizes[np.random.randint(0,3)] for i in range(50)]
CD_data = [cardinal_directions[np.random.randint(0,4)] for i in range(50)]
Timing_data = [Timings[np.random.randint(0,2)] for i in range(50)]
condition_data = [conditions[np.random.randint(0,3)] for i in range(50)]
designation_data = [designations[np.random.randint(0,3)] for i in range(50)]

dictionary = {
    "county": counties,
    "size": size_data,
    "cardinal direction": CD_data,
    "timing": Timing_data,
    "condition": condition_data,
    "designation": designation_data
}

new_df = pd.DataFrame(dictionary)
new_df
# Out:
#                     county    size cardinal direction     timing  condition  \
# 0       Los Angeles County    high               East  full time    abysmal
# 1              Cook County   small              North  part time    abysmal
# 2            Harris County  medium              South  full time       fine
# 3          Maricopa County   small              South  part time       fine
# 4         San Diego County  medium              South  part time    abysmal
# 5            Orange County   small              North  part time    abysmal
# 6        Miami-Dade County    high               West  full time    abysmal
# 7            Dallas County  medium               West  part time  excellent
# 8             Kings County    high               West  part time    abysmal
# 9         Riverside County  medium              North  full time    abysmal
# 10           Queens County   small              South  full time       fine
# 11            Clark County  medium               East  full time  excellent
# 12          Tarrant County    high               East  part time       fine
# 13      Santa Clara County    high               East  full time       fine
# 14          Broward County  medium               East  full time  excellent
# 15            Bexar County    high              North  full time       fine
# 16            Wayne County    high               West  part time  excellent
# 17          Alameda County  medium               East  part time  excellent
# 18        Middlesex County   small               West  full time       fine
# 19       Sacramento County   small              South  full time    abysmal
# 20     Philadelphia County  medium               West  full time       fine
# 21        Allegheny County  medium              South  part time  excellent
# 22           Fresno County   small              North  part time  excellent
# 23     Hillsborough County   small              South  part time  excellent
# 24         New York County   small              South  part time    abysmal
# 25       Palm Beach County   small               East  full time    abysmal
# 26         Cuyahoga County  medium              South  full time  excellent
# 27         Honolulu County    high               West  part time    abysmal
# 28           Travis County   small              North  part time  excellent
# 29          Fairfax County    high               East  part time  excellent
# 30         Hennepin County  medium               West  part time       fine
# 31        Salt Lake County   small              South  full time       fine
# 32           Nassau County  medium              North  full time       fine
# 33           DuPage County   small              South  part time    abysmal
# 34          Oakland County   small               East  part time       fine
# 35      Orange County (FL)    high              North  full time  excellent
# 36  Montgomery County (MD)  medium              South  part time  excellent
# 37          El Paso County    high               East  full time    abysmal
# 38        Baltimore County  medium               East  full time       fine
# 39       Miami County (OH)   small               East  part time       fine
# 40        King County (WA)    high              South  full time    abysmal
# 41        Milwaukee County    high               West  part time  excellent
# 42             Wake County    high              South  full time    abysmal
# 43            Tulsa County    high              South  full time    abysmal
# 44             Pima County    high               East  full time    abysmal
# 45           Bergen County    high               East  part time  excellent
# 46           Fulton County    high               East  part time  excellent
# 47       Gloucester County   small               West  full time  excellent
# 48   San Bernardino County    high               East  part time       fine
# 49           Hudson County    high              South  full time    abysmal
#
#    designation
# 0      manager
# 1    team lead
# 2      janitor
# 3      janitor
# 4    team lead
# 5    team lead
# 6      janitor
# 7      janitor
# 8      manager
# 9      manager
# 10     manager
# 11     manager
# 12     janitor
# 13     manager
# 14     manager
# 15   team lead
# 16     janitor
# 17     janitor
# 18     janitor
# 19     manager
# 20     manager
# 21   team lead
# 22     janitor
# 23     manager
# 24     manager
# 25   team lead
# 26     janitor
# 27     manager
# 28     manager
# 29     janitor
# 30     manager
# 31     manager
# 32     janitor
# 33     manager
# 34     janitor
# 35     janitor
# 36   team lead
# 37     janitor
# 38     manager
# 39   team lead
# 40     janitor
# 41   team lead
# 42     manager
# 43   team lead
# 44     janitor
# 45     janitor
# 46     janitor
# 47     manager
# 48   team lead
# 49     manager
